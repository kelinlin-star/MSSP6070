# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/MyDrive/MSSP6070/Assignments/Week 7/InternetSales.csv'
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_csv(file_path, encoding='ISO-8859-1')
# Out:
# /tmp/ipython-input-1438142135.py:4: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
data['OrderDate'] = pd.to_datetime(data['OrderDate'], errors='coerce')
data['Year'] = data['OrderDate'].dt.year
sales_by_year = data.groupby('Year')['SalesAmount'].sum().reset_index()
plt.figure(figsize=(10,6))
plt.bar(sales_by_year['Year'], sales_by_year['SalesAmount'])
plt.xlabel('Year')
plt.ylabel('Total Sales Amount')
plt.title('Yearly Sales')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
